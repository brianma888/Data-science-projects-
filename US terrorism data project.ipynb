# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('plots.csv')

# %%
df.head()
# Out:
#    plot_ID                          plot_name plot_ideology    plot_status  \
# 0      1.0  2002 Los Angeles Airport Shooting      Jihadist  Not Prevented
# 1      2.0       2002 South Florida Bomb Plot      Jihadist      Prevented
# 2      3.0         2003 Kuwait Grenade Attack      Jihadist  Not Prevented
# 3      4.0                  2002 Padilla Plot      Jihadist      Prevented
# 4      5.0       2004 Herald Square Bomb Plot      Jihadist      Prevented
#
#                                  prevention_method attack_date  \
# 0                                              NaN    7/4/2002
# 1                             Family/Community Tip         NaN
# 2                                              NaN         NaN
# 3  Non-NSA Intelligence Provided by CIA, FBI, etc.         NaN
# 4                             Family/Community Tip         NaN
#
#    victims_wounded  victims_killed
# 0              4.0             2.0
# 1              0.0             0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 8 columns):
# plot_ID              205 non-null float64
# plot_name            216 non-null object
# plot_ideology        215 non-null object
# plot_status          195 non-null object
# prevention_method    166 non-null object
# attack_date          34 non-null object
# victims_wounded      202 non-null float64
# victims_killed       212 non-null float64
# dtypes: float64(3), object(5)
# memory usage: 13.6+ KB

# %%
df.shape
# Out:
# (216, 8)

# %%
df1=pd.read_csv('suspects.csv')

# %%
df1.head()
# Out:
#    suspect_ID   first_name  last_name            full_name   sex   age  \
# 0           1    Zacharias  Moussaoui  Zacharias Moussaoui  Male  33.0
# 1           2      Richard       Reid         Richard Reid  Male  28.0
# 2           3  John Walker      Lindh    John Walker Lindh  Male  20.0
# 3           4          Ali   al-Marri         Ali al-Marri  Male  36.0
# 4           5        Imran    Mandhai        Imran Mandhai  Male  19.0
#
#   marital_status  citizenship_status last_residency_state  \
# 0      Unmarried   Nonimmigrant Visa                  NaN
# 1      Unmarried             Unknown                  NaN
# 2      Unmarried     US Born Citizen             Virginia
# 3        Married   Nonimmigrant Visa             Illinois
# 4      Unmarried  Permanent Resident              Florida
#
#   last_residency_country      ...       military_target awlaki_contact  \
# 0                    NaN      ...                    No           None
# ...

# %%
df.head()
# Out:
#    plot_ID                          plot_name plot_ideology    plot_status  \
# 0      1.0  2002 Los Angeles Airport Shooting      Jihadist  Not Prevented
# 1      2.0       2002 South Florida Bomb Plot      Jihadist      Prevented
# 2      3.0         2003 Kuwait Grenade Attack      Jihadist  Not Prevented
# 3      4.0                  2002 Padilla Plot      Jihadist      Prevented
# 4      5.0       2004 Herald Square Bomb Plot      Jihadist      Prevented
#
#                                  prevention_method attack_date  \
# 0                                              NaN    7/4/2002
# 1                             Family/Community Tip         NaN
# 2                                              NaN         NaN
# 3  Non-NSA Intelligence Provided by CIA, FBI, etc.         NaN
# 4                             Family/Community Tip         NaN
#
#    victims_wounded  victims_killed
# 0              4.0             2.0
# 1              0.0             0.0
# ...

# %%
Top10=df.sort_values(by=['victims_wounded'],ascending=False).head(10)

# %%
Top10.reset_index(inplace=True)

# %%
Top10
#These are the top 10 plots hich causes the most injuries
# Out:
#    index  plot_ID                                  plot_name plot_ideology  \
# 0    114    116.0               2013 Boston Marathon Bombing      Jihadist
# 1    182    184.0           2016 Orlando Night Club Shooting      Jihadist
# 2     14     15.0                    2009 Fort Hood Shooting      Jihadist
# 3    191    193.0     2016 New York City-New Jersey Bombings      Jihadist
# 4    175    177.0               2015 San Bernardino Shooting      Jihadist
# 5      2      3.0                 2003 Kuwait Grenade Attack      Jihadist
# 6    190    192.0                2016 Dallas Police Shooting     Left Wing
# 7    211      NaN          2016 Ohio State University attack      Jihadist
# 8    193    195.0               2016 St. Cloud Mall Stabbing      Jihadist
# 9    172    174.0  2015 Colorado Planned Parenthood Shooting    Right Wing
#
#      plot_status prevention_method attack_date  victims_wounded  \
# 0  Not Prevented               NaN   4/15/2013            170.0
# ...

# %%
Top10comparison=Top10.groupby(by='plot_ideology').sum()

# %%
Top10comparison.reset_index(inplace=True)

# %%
Top10comparison
# Out:
#   plot_ideology  index  plot_ID  victims_wounded  victims_killed
# 0      Jihadist   1082    883.0            343.0            82.0
# 1     Left Wing    190    192.0             11.0             5.0
# 2    Right Wing    172    174.0              9.0             3.0

# %%
sns.set_style('darkgrid')
sns.barplot(data=Top10comparison,x='plot_ideology',y='victims_wounded')
plt.title('Amount of injuries each ideology does in Top10 injuries plots')
plt.xlabel('Types of ideology')
# Out:
# Text(0.5, 0, 'Types of ideology')

# %%
Top10kill=Top10[['plot_name','plot_ideology','victims_killed']]
Top10kill.sort_values(by='victims_killed',ascending=False)
# Out:
#                                    plot_name plot_ideology  victims_killed
# 1           2016 Orlando Night Club Shooting      Jihadist            49.0
# 4               2015 San Bernardino Shooting      Jihadist            14.0
# 2                    2009 Fort Hood Shooting      Jihadist            13.0
# 6                2016 Dallas Police Shooting     Left Wing             5.0
# 0               2013 Boston Marathon Bombing      Jihadist             4.0
# 9  2015 Colorado Planned Parenthood Shooting    Right Wing             3.0
# 5                 2003 Kuwait Grenade Attack      Jihadist             2.0
# 3     2016 New York City-New Jersey Bombings      Jihadist             0.0
# 7          2016 Ohio State University attack      Jihadist             0.0
# 8               2016 St. Cloud Mall Stabbing      Jihadist             0.0

# %%
df.head()
# Out:
#    plot_ID                          plot_name plot_ideology    plot_status  \
# 0      1.0  2002 Los Angeles Airport Shooting      Jihadist  Not Prevented
# 1      2.0       2002 South Florida Bomb Plot      Jihadist      Prevented
# 2      3.0         2003 Kuwait Grenade Attack      Jihadist  Not Prevented
# 3      4.0                  2002 Padilla Plot      Jihadist      Prevented
# 4      5.0       2004 Herald Square Bomb Plot      Jihadist      Prevented
#
#                                  prevention_method attack_date  \
# 0                                              NaN    7/4/2002
# 1                             Family/Community Tip         NaN
# 2                                              NaN         NaN
# 3  Non-NSA Intelligence Provided by CIA, FBI, etc.         NaN
# 4                             Family/Community Tip         NaN
#
#    victims_wounded  victims_killed
# 0              4.0             2.0
# 1              0.0             0.0
# ...

# %%
Ideology=df['plot_ideology'].value_counts()
#Jihadist is the most common ideology for plots

# %%
Ideology
# Out:
# Jihadist      195
# Right Wing     19
# Left Wing       1
# Name: plot_ideology, dtype: int64

# %%
ideology=pd.DataFrame(df['plot_ideology'].value_counts())
ideology.reset_index(inplace=True)

# %%
ideology
# Out:
#         index  plot_ideology
# 0    Jihadist            195
# 1  Right Wing             19
# 2   Left Wing              1

# %%
plt.figure(figsize=(15,10))
sns.barplot(data=ideology,x='index',y='plot_ideology')
plt.xlabel('plot_ideology')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
df.head()
# Out:
#    plot_ID                          plot_name plot_ideology    plot_status  \
# 0      1.0  2002 Los Angeles Airport Shooting      Jihadist  Not Prevented
# 1      2.0       2002 South Florida Bomb Plot      Jihadist      Prevented
# 2      3.0         2003 Kuwait Grenade Attack      Jihadist  Not Prevented
# 3      4.0                  2002 Padilla Plot      Jihadist      Prevented
# 4      5.0       2004 Herald Square Bomb Plot      Jihadist      Prevented
#
#                                  prevention_method attack_date  \
# 0                                              NaN    7/4/2002
# 1                             Family/Community Tip         NaN
# 2                                              NaN         NaN
# 3  Non-NSA Intelligence Provided by CIA, FBI, etc.         NaN
# 4                             Family/Community Tip         NaN
#
#    victims_wounded  victims_killed
# 0              4.0             2.0
# 1              0.0             0.0
# ...

# %%
Prev_method=pd.DataFrame(df['prevention_method'].value_counts())
Prev_method
Prev_method.reset_index(inplace=True)
Prev_method
# Out:
#                                                index  prevention_method
# 0                                            Unknown                 50
# 1                                          Informant                 39
# 2                               Family/Community Tip                 19
# 3                            Militant Self-Disclosed                 16
# 4    Non-NSA Intelligence Provided by CIA, FBI, etc.                 12
# 5                         Suspicious Activity Report                 11
# 6                            Routine Law Enforcement                 10
# 7  NSA Surveillance Targeting Non-US Persons Unde...                  5
# 8           NSA Surveillance Under Unknown Authority                  3
# 9              NSA Bulk Collection Under Section 215                  1

# %%
Prev_method.columns=['method','number']

# %%
Prev_method
# Out:
#                                               method  number
# 0                                            Unknown      50
# 1                                          Informant      39
# 2                               Family/Community Tip      19
# 3                            Militant Self-Disclosed      16
# 4    Non-NSA Intelligence Provided by CIA, FBI, etc.      12
# 5                         Suspicious Activity Report      11
# 6                            Routine Law Enforcement      10
# 7  NSA Surveillance Targeting Non-US Persons Unde...       5
# 8           NSA Surveillance Under Unknown Authority       3
# 9              NSA Bulk Collection Under Section 215       1

# %%
plt.figure(figsize=(15,10))
sns.barplot(data=Prev_method,x='method',y='number')
plt.xticks(rotation=90)
plt.title('methods and number')
# Out:
# Text(0.5, 1.0, 'methods and number')

# %%
Top10comparison
# Out:
#   plot_ideology  index  plot_ID  victims_wounded  victims_killed
# 0      Jihadist   1082    883.0            343.0            82.0
# 1     Left Wing    190    192.0             11.0             5.0
# 2    Right Wing    172    174.0              9.0             3.0

# %%
df.head()
# Out:
#    plot_ID                          plot_name plot_ideology    plot_status  \
# 0      1.0  2002 Los Angeles Airport Shooting      Jihadist  Not Prevented
# 1      2.0       2002 South Florida Bomb Plot      Jihadist      Prevented
# 2      3.0         2003 Kuwait Grenade Attack      Jihadist  Not Prevented
# 3      4.0                  2002 Padilla Plot      Jihadist      Prevented
# 4      5.0       2004 Herald Square Bomb Plot      Jihadist      Prevented
#
#                                  prevention_method attack_date  \
# 0                                              NaN    7/4/2002
# 1                             Family/Community Tip         NaN
# 2                                              NaN         NaN
# 3  Non-NSA Intelligence Provided by CIA, FBI, etc.         NaN
# 4                             Family/Community Tip         NaN
#
#    victims_wounded  victims_killed
# 0              4.0             2.0
# 1              0.0             0.0
# ...

# %%
plt.figure(figsize=(15,10))
sns.violinplot(data=df,x='plot_ideology',y='victims_wounded')

# %%
df1.head()
#Let's first explore the citizenship_status, see which status owns the largest amount of suspects
# Out:
#    suspect_ID   first_name  last_name            full_name   sex   age  \
# 0           1    Zacharias  Moussaoui  Zacharias Moussaoui  Male  33.0
# 1           2      Richard       Reid         Richard Reid  Male  28.0
# 2           3  John Walker      Lindh    John Walker Lindh  Male  20.0
# 3           4          Ali   al-Marri         Ali al-Marri  Male  36.0
# 4           5        Imran    Mandhai        Imran Mandhai  Male  19.0
#
#   marital_status  citizenship_status last_residency_state  \
# 0      Unmarried   Nonimmigrant Visa                  NaN
# 1      Unmarried             Unknown                  NaN
# 2      Unmarried     US Born Citizen             Virginia
# 3        Married   Nonimmigrant Visa             Illinois
# 4      Unmarried  Permanent Resident              Florida
#
#   last_residency_country      ...       military_target awlaki_contact  \
# 0                    NaN      ...                    No           None
# ...

# %%
status_count=pd.DataFrame(df1['citizenship_status'].value_counts())
status_count
status_count.reset_index(inplace=True)
status_count
status_count.columns=['status','number']
status_count
# Out:
#                       status  number
# 0            US Born Citizen     188
# 1        Naturalized Citizen      83
# 2         Permanent Resident      43
# 3                    Unknown      38
# 4                    Refugee      13
# 5  Citizen of Unknown Status      12
# 6          Nonimmigrant Visa      11
# 7          Illegal Immigrant       8

# %%
plt.figure(figsize=(15,10))
sns.barplot(data=status_count,x='status',y='number',color='blue')
plt.title('Status X suspect number')
# Out:
# Text(0.5, 1.0, 'Status X suspect number')

# %%
df1
# Out:
#      suspect_ID          first_name      last_name                  full_name  \
# 0             1           Zacharias      Moussaoui        Zacharias Moussaoui
# 1             2             Richard           Reid               Richard Reid
# 2             3         John Walker          Lindh          John Walker Lindh
# 3             4                 Ali       al-Marri               Ali al-Marri
# 4             5               Imran        Mandhai              Imran Mandhai
# 5             6        Shueyb Mossa         Jokhan        Shueyb Mossa Jokhan
# 6             7                Semi          Osman                 Semi Osman
# 7             8        Ernest James         Ujaama        Ernest James Ujaama
# 8             9            Jaber A.        Elbaneh           Jaber A. Elbaneh
# 9            10  October Martinique          Lewis   October Martinique Lewis
# 10           11       Habis Abdulla       al Saoub     Habis Abdulla al Saoub
# ...

# %%
#Let's check sex now 
df1['sex'].value_counts()
#It can be seen that male makes up a major proportion of suspects
# Out:
# Male      368
# Female     28
# Name: sex, dtype: int64

# %%
sex_count
# Out:
#         sex
# Male    368
# Female   28

# %%
sns.barplot(data=sex_count,x=sex_count.index,y='sex')
plt.title('Sex count')
plt.xlabel('Gender')
plt.ylabel('Number of suspects')
# Out:
# Text(0, 0.5, 'Number of suspects')

# %%
df1.head()
# Out:
#    suspect_ID   first_name  last_name            full_name   sex   age  \
# 0           1    Zacharias  Moussaoui  Zacharias Moussaoui  Male  33.0
# 1           2      Richard       Reid         Richard Reid  Male  28.0
# 2           3  John Walker      Lindh    John Walker Lindh  Male  20.0
# 3           4          Ali   al-Marri         Ali al-Marri  Male  36.0
# 4           5        Imran    Mandhai        Imran Mandhai  Male  19.0
#
#   marital_status  citizenship_status last_residency_state  \
# 0      Unmarried   Nonimmigrant Visa                  NaN
# 1      Unmarried             Unknown                  NaN
# 2      Unmarried     US Born Citizen             Virginia
# 3        Married   Nonimmigrant Visa             Illinois
# 4      Unmarried  Permanent Resident              Florida
#
#   last_residency_country      ...       military_target awlaki_contact  \
# 0                    NaN      ...                    No           None
# ...

# %%
State_count=pd.DataFrame(df1['last_residency_state'].value_counts())

# %%
State_count
State_count.drop(columns='level_0',inplace=True)

# %%
State_count
State_count.columns=['State','Number of suspects']

# %%
State_count.head()
# Out:
#         State  Number of suspects
# 0    New York                  60
# 1    Virginia                  40
# 2   Minnesota                  40
# 3  California                  32
# 4     Florida                  28

# %%
plt.figure(figsize=(20,15))
sns.barplot(data=State_count,x='Number of suspects',y='State')
plt.title('Number of suspets in each state in US')
# Out:
# Text(0.5, 1.0, 'Number of suspets in each state in US')

# %%
State_count.head()
# Out:
#         State  Number of suspects
# 0    New York                  60
# 1    Virginia                  40
# 2   Minnesota                  40
# 3  California                  32
# 4     Florida                  28

# %%
df1
# Out:
#      suspect_ID          first_name      last_name                  full_name  \
# 0             1           Zacharias      Moussaoui        Zacharias Moussaoui
# 1             2             Richard           Reid               Richard Reid
# 2             3         John Walker          Lindh          John Walker Lindh
# 3             4                 Ali       al-Marri               Ali al-Marri
# 4             5               Imran        Mandhai              Imran Mandhai
# 5             6        Shueyb Mossa         Jokhan        Shueyb Mossa Jokhan
# 6             7                Semi          Osman                 Semi Osman
# 7             8        Ernest James         Ujaama        Ernest James Ujaama
# 8             9            Jaber A.        Elbaneh           Jaber A. Elbaneh
# 9            10  October Martinique          Lewis   October Martinique Lewis
# 10           11       Habis Abdulla       al Saoub     Habis Abdulla al Saoub
# ...

# %%
us_exp=pd.DataFrame(df1['us_military_experience'].value_counts())
us_exp
# Out:
#      us_military_experience
# No                      368
# Yes                      28

# %%
plt.figure(figsize=(15,10))
sns.barplot(data=us_exp,x=us_exp.index,y='us_military_experience')
plt.title('US military experience X suspect number')
plt.ylabel('Suspect number')
plt.xlabel('US military experience')
# Out:
# Text(0.5, 0, 'US military experience')

# %%
df1.head()
# Out:
#    suspect_ID   first_name  last_name            full_name   sex   age  \
# 0           1    Zacharias  Moussaoui  Zacharias Moussaoui  Male  33.0
# 1           2      Richard       Reid         Richard Reid  Male  28.0
# 2           3  John Walker      Lindh    John Walker Lindh  Male  20.0
# 3           4          Ali   al-Marri         Ali al-Marri  Male  36.0
# 4           5        Imran    Mandhai        Imran Mandhai  Male  19.0
#
#   marital_status  citizenship_status last_residency_state  \
# 0      Unmarried   Nonimmigrant Visa                  NaN
# 1      Unmarried             Unknown                  NaN
# 2      Unmarried     US Born Citizen             Virginia
# 3        Married   Nonimmigrant Visa             Illinois
# 4      Unmarried  Permanent Resident              Florida
#
#   last_residency_country      ...       military_target awlaki_contact  \
# 0                    NaN      ...                    No           None
# ...

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=df1,x='citizenship_status',hue='suspect_status')
plt.legend(loc=2)
