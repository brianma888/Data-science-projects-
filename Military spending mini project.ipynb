# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Military Expenditure.csv')

# %%
df.head()
# Out:
#           Name Code     Type                      Indicator Name  1960  1961  \
# 0        Aruba  ABW  Country  Military expenditure (current USD)   NaN   NaN
# 1  Afghanistan  AFG  Country  Military expenditure (current USD)   NaN   NaN
# 2       Angola  AGO  Country  Military expenditure (current USD)   NaN   NaN
# 3      Albania  ALB  Country  Military expenditure (current USD)   NaN   NaN
# 4      Andorra  AND  Country  Military expenditure (current USD)   NaN   NaN
#
#    1962  1963  1964  1965      ...               2009          2010  \
# 0   NaN   NaN   NaN   NaN      ...                NaN           NaN
# 1   NaN   NaN   NaN   NaN      ...       2.518695e+08  2.981469e+08
# 2   NaN   NaN   NaN   NaN      ...       3.311193e+09  3.500795e+09
# 3   NaN   NaN   NaN   NaN      ...       1.827369e+08  1.858932e+08
# 4   NaN   NaN   NaN   NaN      ...                NaN           NaN
#
#            2011          2012          2013          2014          2015  \
# ...

# %%
df.drop(columns='Indicator Name',inplace=True)

# %%
df.head()
# Out:
#           Name Code     Type  1960  1961  1962  1963  1964  1965  1966  \
# 0        Aruba  ABW  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  Afghanistan  AFG  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       Angola  AGO  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3      Albania  ALB  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4      Andorra  AND  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#        ...               2009          2010          2011          2012  \
# 0      ...                NaN           NaN           NaN           NaN
# 1      ...       2.518695e+08  2.981469e+08  3.258070e+08  2.385834e+08
# 2      ...       3.311193e+09  3.500795e+09  3.639496e+09  4.144635e+09
# 3      ...       1.827369e+08  1.858932e+08  1.970068e+08  1.832047e+08
# 4      ...                NaN           NaN           NaN           NaN
#
#            2013          2014          2015          2016          2017  \
# ...

# %%
World=df[df['Name']=='World']

# %%
World
# Out:
#       Name Code                            Type  1960  1961  1962  1963  1964  \
# 257  World  WLD  Regions Clubbed Geographically   NaN   NaN   NaN   NaN   NaN
#
#      1965  1966      ...               2009          2010          2011  \
# 257   NaN   NaN      ...       1.550000e+12  1.630000e+12  1.730000e+12
#
#              2012          2013          2014          2015          2016  \
# 257  1.740000e+12  1.740000e+12  1.740000e+12  1.640000e+12  1.630000e+12
#
#              2017          2018
# 257  1.700000e+12  1.780000e+12
#
# [1 rows x 62 columns]

# %%
World1=df[df['Name']=='World']

# %%
World1.drop(columns=['Code','Type'],axis=1,inplace=True)

# %%
World1
# Out:
#       Name  1960  1961  1962  1963  1964  1965  1966  1967  1968  \
# 257  World   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#          ...               2009          2010          2011          2012  \
# 257      ...       1.550000e+12  1.630000e+12  1.730000e+12  1.740000e+12
#
#              2013          2014          2015          2016          2017  \
# 257  1.740000e+12  1.740000e+12  1.640000e+12  1.630000e+12  1.700000e+12
#
#              2018
# 257  1.780000e+12
#
# [1 rows x 60 columns]

# %%
World1.set_index('Name',inplace=True)

# %%
World1
# Out:
#        1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  \
# Name
# World   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#            ...               2009          2010          2011          2012  \
# Name       ...
# World      ...       1.550000e+12  1.630000e+12  1.730000e+12  1.740000e+12
#
#                2013          2014          2015          2016          2017  \
# Name
# World  1.740000e+12  1.740000e+12  1.640000e+12  1.630000e+12  1.700000e+12
#
#                2018
# Name
# World  1.780000e+12
#
# [1 rows x 59 columns]

# %%
World1.index.rename('Year')
# Out:
# Index(['World'], dtype='object', name='Year')

# %%
World1
# Out:
#        1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  \
# Name
# World   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#            ...               2009          2010          2011          2012  \
# Name       ...
# World      ...       1.550000e+12  1.630000e+12  1.730000e+12  1.740000e+12
#
#                2013          2014          2015          2016          2017  \
# Name
# World  1.740000e+12  1.740000e+12  1.640000e+12  1.630000e+12  1.700000e+12
#
#                2018
# Name
# World  1.780000e+12
#
# [1 rows x 59 columns]

# %%
World1=World1.T

# %%
World1
# Out:
# Name         World
# 1960           NaN
# 1961           NaN
# 1962           NaN
# 1963           NaN
# 1964           NaN
# 1965           NaN
# 1966           NaN
# 1967           NaN
# 1968           NaN
# 1969           NaN
# 1970           NaN
# 1971           NaN
# 1972           NaN
# 1973           NaN
# 1974           NaN
# 1975           NaN
# 1976           NaN
# 1977           NaN
# 1978           NaN
# 1979           NaN
# 1980  3.640000e+11
# 1981  4.000000e+11
# 1982           NaN
# 1983           NaN
# 1984  4.480000e+11
# 1985  4.740000e+11
# 1986  5.200000e+11
# 1987  5.880000e+11
# 1988  6.270000e+11
# 1989  6.450000e+11
# 1990  7.000000e+11
# 1991  6.850000e+11
# 1992  7.170000e+11
# 1993  6.860000e+11
# 1994  6.950000e+11
# 1995  7.170000e+11
# 1996  7.160000e+11
# 1997  7.140000e+11
# 1998  6.960000e+11
# 1999  7.090000e+11
# 2000  7.300000e+11
# 2001  7.420000e+11
# 2002  8.020000e+11
# 2003  9.370000e+11
# 2004  1.060000e+12
# 2005  1.150000e+12
# ...

# %%
len(World1)
# Out:
# 59

# %%
World1[30:].head()
# Out:
# Name         World
# 1990  7.000000e+11
# 1991  6.850000e+11
# 1992  7.170000e+11
# 1993  6.860000e+11
# 1994  6.950000e+11

# %%
World1.index.rename('Year',inplace=True)

# %%
World1.head()
# Out:
# Name  World
# Year
# 1960    NaN
# 1961    NaN
# 1962    NaN
# 1963    NaN
# 1964    NaN

# %%
World1[30:].head()
# Out:
# Name         World
# Year
# 1990  7.000000e+11
# 1991  6.850000e+11
# 1992  7.170000e+11
# 1993  6.860000e+11
# 1994  6.950000e+11

# %%
World2=World1[30:]

# %%
World2.head()
# Out:
# Name         World
# Year
# 1990  7.000000e+11
# 1991  6.850000e+11
# 1992  7.170000e+11
# 1993  6.860000e+11
# 1994  6.950000e+11

# %%
import seaborn as sns

# %%
World2.reset_index(inplace=True)

# %%
sns.set_style('whitegrid')
sns.lineplot(data=World2,x=World2['Year'],y='World',markers=True,markersize=9)
plt.xticks(rotation=90)
plt.xlabel('Year')
plt.ylabel('Billions in USD')
plt.title('World total military spending')
# Out:
# Text(0.5, 1.0, 'World total military spending')

# %%
df[df['Type']=='Country']
# Out:
#                                Name Code     Type          1960          1961  \
# 0                             Aruba  ABW  Country           NaN           NaN
# 1                       Afghanistan  AFG  Country           NaN           NaN
# 2                            Angola  AGO  Country           NaN           NaN
# 3                           Albania  ALB  Country           NaN           NaN
# 4                           Andorra  AND  Country           NaN           NaN
# 6              United Arab Emirates  ARE  Country           NaN           NaN
# 7                         Argentina  ARG  Country           NaN           NaN
# 8                           Armenia  ARM  Country           NaN           NaN
# 10              Antigua and Barbuda  ATG  Country           NaN           NaN
# 11                        Australia  AUS  Country  4.597601e+08  4.709601e+08
# 12                          Austria  AUT  Country  9.155910e+07  9.102985e+07
# ...

# %%
df.set_index('Name',inplace=True)

# %%
df.head()
# Out:
#             Code     Type  1960  1961  1962  1963  1964  1965  1966  1967  \
# Name
# Aruba        ABW  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan  AFG  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola       AGO  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania      ALB  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Andorra      AND  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                  ...               2009          2010          2011  \
# Name             ...
# Aruba            ...                NaN           NaN           NaN
# Afghanistan      ...       2.518695e+08  2.981469e+08  3.258070e+08
# Angola           ...       3.311193e+09  3.500795e+09  3.639496e+09
# Albania          ...       1.827369e+08  1.858932e+08  1.970068e+08
# Andorra          ...                NaN           NaN           NaN
#
#                      2012          2013          2014          2015  \
# Name
# ...

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#           Name Code     Type  1960  1961  1962  1963  1964  1965  1966  \
# 0        Aruba  ABW  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  Afghanistan  AFG  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       Angola  AGO  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3      Albania  ALB  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4      Andorra  AND  Country   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#        ...               2009          2010          2011          2012  \
# 0      ...                NaN           NaN           NaN           NaN
# 1      ...       2.518695e+08  2.981469e+08  3.258070e+08  2.385834e+08
# 2      ...       3.311193e+09  3.500795e+09  3.639496e+09  4.144635e+09
# 3      ...       1.827369e+08  1.858932e+08  1.970068e+08  1.832047e+08
# 4      ...                NaN           NaN           NaN           NaN
#
#            2013          2014          2015          2016          2017  \
# ...

# %%
Nations=df[df['Type']=='Country']

# %%
Nations.head()
Nations.drop(columns=['Code','Type'],inplace=True)

# %%
Nations
# Out:
#                                Name          1960          1961          1962  \
# 0                             Aruba           NaN           NaN           NaN
# 1                       Afghanistan           NaN           NaN           NaN
# 2                            Angola           NaN           NaN           NaN
# 3                           Albania           NaN           NaN           NaN
# 4                           Andorra           NaN           NaN           NaN
# 6              United Arab Emirates           NaN           NaN           NaN
# 7                         Argentina           NaN           NaN  3.051624e+08
# 8                           Armenia           NaN           NaN           NaN
# 10              Antigua and Barbuda           NaN           NaN           NaN
# 11                        Australia  4.597601e+08  4.709601e+08  4.894401e+08
# 12                          Austria  9.155910e+07  9.102985e+07  1.000270e+08
# ...

# %%
Nations.set_index('Name',inplace=True)

# %%
Nations
# Out:
#                                         1960          1961          1962  \
# Name
# Aruba                                    NaN           NaN           NaN
# Afghanistan                              NaN           NaN           NaN
# Angola                                   NaN           NaN           NaN
# Albania                                  NaN           NaN           NaN
# Andorra                                  NaN           NaN           NaN
# United Arab Emirates                     NaN           NaN           NaN
# Argentina                                NaN           NaN  3.051624e+08
# Armenia                                  NaN           NaN           NaN
# Antigua and Barbuda                      NaN           NaN           NaN
# Australia                       4.597601e+08  4.709601e+08  4.894401e+08
# Austria                         9.155910e+07  9.102985e+07  1.000270e+08
# Azerbaijan                               NaN           NaN           NaN
# ...

# %%
Nations=Nations.dropna(axis=0,how='all')

# %%
Nations
# Out:
#                                   1960          1961          1962  \
# Name
# Afghanistan                        NaN           NaN           NaN
# Angola                             NaN           NaN           NaN
# Albania                            NaN           NaN           NaN
# United Arab Emirates               NaN           NaN           NaN
# Argentina                          NaN           NaN  3.051624e+08
# Armenia                            NaN           NaN           NaN
# Australia                 4.597601e+08  4.709601e+08  4.894401e+08
# Austria                   9.155910e+07  9.102985e+07  1.000270e+08
# Azerbaijan                         NaN           NaN           NaN
# Burundi                            NaN           NaN  8.420000e+06
# Belgium                   3.832202e+08  3.912188e+08  4.222208e+08
# Benin                     1.301005e+06  2.173204e+06  2.734538e+06
# Burkina Faso              1.268378e+06  1.643154e+06  4.901761e+06
# ...

# %%
Nations=Nations.T

# %%
Nations
# Out:
# Name   Afghanistan        Angola       Albania  United Arab Emirates  \
# 1960           NaN           NaN           NaN                   NaN
# 1961           NaN           NaN           NaN                   NaN
# 1962           NaN           NaN           NaN                   NaN
# 1963           NaN           NaN           NaN                   NaN
# 1964           NaN           NaN           NaN                   NaN
# 1965           NaN           NaN           NaN                   NaN
# 1966           NaN           NaN           NaN                   NaN
# 1967           NaN           NaN           NaN                   NaN
# 1968           NaN           NaN           NaN                   NaN
# 1969           NaN           NaN           NaN                   NaN
# 1970  2.939586e+06           NaN           NaN                   NaN
# 1971           NaN           NaN           NaN                   NaN
# 1972           NaN           NaN           NaN                   NaN
# ...

# %%
Nations=Nations[30:]

# %%
Nations.head()
# Out:
# Name  Afghanistan        Angola      Albania  United Arab Emirates  \
# 1990          NaN  1.751153e+09          NaN                   NaN
# 1991          NaN  1.031248e+09          NaN                   NaN
# 1992          NaN  7.941388e+08  31559657.48                   NaN
# 1993          NaN  1.774398e+09  39289843.43                   NaN
# 1994          NaN  5.949912e+08  49649504.93                   NaN
#
# Name     Argentina      Armenia     Australia       Austria   Azerbaijan  \
# 1990  2.050908e+09          NaN  6.704214e+09  1.972702e+09          NaN
# 1991  2.858779e+09          NaN  7.023509e+09  1.994056e+09          NaN
# 1992  3.254455e+09          NaN  6.882092e+09  2.139925e+09  11070110.70
# 1993  3.368550e+09  9829763.866  6.733829e+09  2.115115e+09  77519379.84
# 1994  3.754725e+09          NaN  7.459697e+09  2.227561e+09  43942747.06
#
# Name      Burundi     ...           Uruguay  United States   Uzbekistan  \
# ...

# %%
Nations.index.rename('Year',inplace=True)

# %%
Nations.head()
# Out:
# Name  Afghanistan        Angola      Albania  United Arab Emirates  \
# Year
# 1990          NaN  1.751153e+09          NaN                   NaN
# 1991          NaN  1.031248e+09          NaN                   NaN
# 1992          NaN  7.941388e+08  31559657.48                   NaN
# 1993          NaN  1.774398e+09  39289843.43                   NaN
# 1994          NaN  5.949912e+08  49649504.93                   NaN
#
# Name     Argentina      Armenia     Australia       Austria   Azerbaijan  \
# Year
# 1990  2.050908e+09          NaN  6.704214e+09  1.972702e+09          NaN
# 1991  2.858779e+09          NaN  7.023509e+09  1.994056e+09          NaN
# 1992  3.254455e+09          NaN  6.882092e+09  2.139925e+09  11070110.70
# 1993  3.368550e+09  9829763.866  6.733829e+09  2.115115e+09  77519379.84
# 1994  3.754725e+09          NaN  7.459697e+09  2.227561e+09  43942747.06
#
# Name      Burundi     ...           Uruguay  United States   Uzbekistan  \
# Year                  ...
# ...

# %%
Nations=pd.DataFrame((Nations.T['2018']).sort_values(ascending=False))

# %%
Nations.head(10) #Top 10
# Out:
#                             2018
# Name
# United States       6.490000e+11
# China               2.500000e+11
# Saudi Arabia        6.755467e+10
# India               6.651029e+10
# France              6.379968e+10
# Russian Federation  6.138755e+10
# United Kingdom      4.999719e+10
# Germany             4.947063e+10
# Japan               4.661795e+10
# South Korea         4.306997e+10

# %%
import seaborn as sns

# %%
Nations.reset_index(inplace=True)

# %%
Nations=Nations.head(10)

# %%
Nations
# Out:
#                  Name          2018
# 0       United States  6.490000e+11
# 1               China  2.500000e+11
# 2        Saudi Arabia  6.755467e+10
# 3               India  6.651029e+10
# 4              France  6.379968e+10
# 5  Russian Federation  6.138755e+10
# 6      United Kingdom  4.999719e+10
# 7             Germany  4.947063e+10
# 8               Japan  4.661795e+10
# 9         South Korea  4.306997e+10

# %%
sns.barplot(data=Nations,x='Name',y='2018')
plt.tight_layout()
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Spending in US Billions')
# Out:
# Text(37.375, 0.5, 'Spending in US Billions')

# %%
df=df.dropna()

# %%
df.reset_index(drop=True)
# Out:
#                                                  Name Code  \
# 0                                           Australia  AUS
# 1                                             Austria  AUT
# 2                                             Belgium  BEL
# 3                                        Burkina Faso  BFA
# 4                                              Brazil  BRA
# 5                                              Canada  CAN
# 6                                         Switzerland  CHE
# 7                                               Chile  CHL
# 8                                            Colombia  COL
# 9                                          Costa Rica  CRI
# 10                                            Germany  DEU
# 11                                            Denmark  DNK
# 12                                 Dominican Republic  DOM
# 13                         Early-demographic dividend  EAR
# 14                                            Ecuador  ECU
# ...

# %%
df.describe(include='all')
# Out:
#                                                      Name Code     Type  \
# count                                                  66   66       66
# unique                                                 66   66        3
# top     Latin America & the Caribbean (IDA & IBRD coun...  EUU  Country
# freq                                                    1    1       52
# mean                                                  NaN  NaN      NaN
# std                                                   NaN  NaN      NaN
# min                                                   NaN  NaN      NaN
# 25%                                                   NaN  NaN      NaN
# 50%                                                   NaN  NaN      NaN
# 75%                                                   NaN  NaN      NaN
# max                                                   NaN  NaN      NaN
#
#                 1960          1961          1962          1963          1964  \
# ...

# %%
df
# Out:
#                                                   Name Code  \
# 11                                           Australia  AUS
# 12                                             Austria  AUT
# 15                                             Belgium  BEL
# 17                                        Burkina Faso  BFA
# 27                                              Brazil  BRA
# 33                                              Canada  CAN
# 35                                         Switzerland  CHE
# 37                                               Chile  CHL
# 43                                            Colombia  COL
# 46                                          Costa Rica  CRI
# 53                                             Germany  DEU
# 56                                             Denmark  DNK
# 57                                  Dominican Republic  DOM
# 60                          Early-demographic dividend  EAR
# 64                                             Ecuador  ECU
# ...

# %%
df1=df[df['Type']=='Country']

# %%
df1.reset_index(inplace=True)

# %%
df1.drop(columns='index',inplace=True)

# %%
df1['total']=df1.sum(axis=1)

# %%
df1
# Out:
#                   Name Code     Type          1960          1961  \
# 0            Australia  AUS  Country  4.597601e+08  4.709601e+08
# 1              Austria  AUT  Country  9.155910e+07  9.102985e+07
# 2              Belgium  BEL  Country  3.832202e+08  3.912188e+08
# 3         Burkina Faso  BFA  Country  1.268378e+06  1.643154e+06
# 4               Brazil  BRA  Country  3.827298e+08  3.423397e+08
# 5               Canada  CAN  Country  1.702443e+09  1.677821e+09
# 6          Switzerland  CHE  Country  2.000938e+08  2.373684e+08
# 7                Chile  CHL  Country  1.267910e+08  1.609309e+08
# 8             Colombia  COL  Country  7.596081e+07  9.731343e+07
# 9           Costa Rica  CRI  Country  0.000000e+00  0.000000e+00
# 10             Germany  DEU  Country  2.884518e+09  3.266496e+09
# 11             Denmark  DNK  Country  1.611376e+08  1.708377e+08
# 12  Dominican Republic  DOM  Country  3.830000e+07  3.630000e+07
# ...

# %%
df2=df1[['Name','total']]

# %%
df2['total'].sort_values(ascending=False)
# Out:
# 50    3.456825e+13
# 17    3.854566e+12
# 18    3.603883e+12
# 10    3.222129e+12
# 28    3.022476e+12
# 21    1.871210e+12
# 26    1.807030e+12
# 29    1.439967e+12
# 4     1.186871e+12
# 5     1.045662e+12
# 14    1.019980e+12
# 0     1.017816e+12
# 23    8.669617e+11
# 25    8.612628e+11
# 49    8.010180e+11
# 41    7.153597e+11
# 36    6.878465e+11
# 46    4.552173e+11
# 19    4.008771e+11
# 39    3.734017e+11
# 2     3.706383e+11
# 8     3.636536e+11
# 37    3.485658e+11
# 6     3.024603e+11
# 51    2.812504e+11
# 33    2.755116e+11
# 47    2.620732e+11
# 11    2.553039e+11
# 7     2.352230e+11
# 42    2.309228e+11
# 34    2.079249e+11
# 16    1.937706e+11
# 1     1.922399e+11
# 44    1.794758e+11
# 32    1.561491e+11
# 35    1.312510e+11
# 40    1.263565e+11
# 38    1.066647e+11
# 13    7.801286e+10
# 27    6.988215e+10
# 22    6.724897e+10
# 30    6.208139e+10
# 48    3.668895e+10
# 15    3.381833e+10
# 12    1.914673e+10
# 43    1.568299e+10
# 20    1.464852e+10
# ...

# %%
df2.sort_values(by='total',ascending=False,inplace=True)
df2.reset_index(inplace=True)

# %%
df2.drop(columns='index',inplace=True)

# %% [markdown]
# ##

# %%
df2.columns=['index in orig df','Country','total spending']

# %%
df2.head()
# Out:
#    index in orig df         Country  total spending
# 0                50   United States    3.456825e+13
# 1                17          France    3.854566e+12
# 2                18  United Kingdom    3.603883e+12
# 3                10         Germany    3.222129e+12
# 4                28           Japan    3.022476e+12

# %%
plt.figure(figsize=(15,20))
sns.set_style('darkgrid')
sns.barplot(data=df2,x='total spending',y='Country')
plt.title('Total military spending of countries')
# Out:
# Text(0.5, 1.0, 'Total military spending of countries')
