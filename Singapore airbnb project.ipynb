# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')
from plotly import __version__
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
import plotly as py
import plotly.graph_objs as go
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df=pd.read_csv('listings.csv')

# %%
df
# Out:
#             id                                               name    host_id  \
# 0        49091                  COZICOMFORT LONG TERM STAY ROOM 2     266763
# 1        50646                    Pleasant Room along Bukit Timah     227796
# 2        56334                                        COZICOMFORT     266763
# 3        71609                Ensuite Room (Room 1 & 2) near EXPO     367042
# 4        71896                    B&B  Room 1 near Airport & EXPO     367042
# 5        71903                         Room 2-near Airport & EXPO     367042
# 6        71907                   3rd level Jumbo room 5 near EXPO     367042
# 7       241503             Long stay at The Breezy East "Leopard"    1017645
# 8       241508            Long stay at The Breezy East "Plumeria"    1017645
# 9       241510            Long stay at The Breezy East "Red Palm"    1017645
# 10      275343  Conveniently located City Room!( (Phone number...    1439258
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7907 entries, 0 to 7906
# Data columns (total 16 columns):
# id                                7907 non-null int64
# name                              7905 non-null object
# host_id                           7907 non-null int64
# host_name                         7907 non-null object
# neighbourhood_group               7907 non-null object
# neighbourhood                     7907 non-null object
# latitude                          7907 non-null float64
# longitude                         7907 non-null float64
# room_type                         7907 non-null object
# price                             7907 non-null int64
# minimum_nights                    7907 non-null int64
# number_of_reviews                 7907 non-null int64
# last_review                       5149 non-null object
# reviews_per_month                 5149 non-null float64
# calculated_host_listings_count    7907 non-null int64
# ...

# %%
df.shape
# Out:
# (7907, 16)

# %%
df.describe()
# Out:
#                  id       host_id     latitude    longitude         price  \
# count  7.907000e+03  7.907000e+03  7907.000000  7907.000000   7907.000000
# mean   2.338862e+07  9.114481e+07     1.314192   103.848787    169.332996
# std    1.016416e+07  8.190910e+07     0.030577     0.043675    340.187599
# min    4.909100e+04  2.366600e+04     1.243870   103.646560      0.000000
# 25%    1.582180e+07  2.305808e+07     1.295795   103.835825     65.000000
# 50%    2.470627e+07  6.344891e+07     1.311030   103.849410    124.000000
# 75%    3.234850e+07  1.553811e+08     1.322110   103.872535    199.000000
# max    3.811276e+07  2.885676e+08     1.454590   103.973420  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count     7907.000000        7907.000000        5149.000000
# mean        17.510054          12.807386           1.043669
# std         42.094616          29.707746           1.285851
# ...

# %%
df.head()
# Out:
#       id                                 name  host_id  host_name  \
# 0  49091    COZICOMFORT LONG TERM STAY ROOM 2   266763  Francesca
# 1  50646      Pleasant Room along Bukit Timah   227796    Sujatha
# 2  56334                          COZICOMFORT   266763  Francesca
# 3  71609  Ensuite Room (Room 1 & 2) near EXPO   367042    Belinda
# 4  71896      B&B  Room 1 near Airport & EXPO   367042    Belinda
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0        North Region     Woodlands   1.44255  103.79580  Private room     83
# 1      Central Region   Bukit Timah   1.33235  103.78521  Private room     81
# 2        North Region     Woodlands   1.44246  103.79667  Private room     69
# 3         East Region      Tampines   1.34541  103.95712  Private room    206
# 4         East Region      Tampines   1.34567  103.95963  Private room     94
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
df['neighbourhood_group'].value_counts()
##Shows that central region has the largest amount of airbnb rooms
# Out:
# Central Region       6309
# West Region           540
# East Region           508
# North-East Region     346
# North Region          204
# Name: neighbourhood_group, dtype: int64

# %%
df['host_name'].value_counts().head(5)
#These are the five hosts which has the highest number of hosts
# Out:
# Jay         290
# Alvin       249
# Richards    157
# Aaron       145
# Rain        115
# Name: host_name, dtype: int64

# %%
df.isna().sum()
#Returns the number of null values in each column
# Out:
# id                                   0
# name                                 2
# host_id                              0
# host_name                            0
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       2758
# reviews_per_month                 2758
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
##Since last_review and reviews_per_month will not be needed, we will drop it 
df.drop(columns=['last_review','reviews_per_month'],inplace=True)

# %%
df.head()
# Out:
#       id                                 name  host_id  host_name  \
# 0  49091    COZICOMFORT LONG TERM STAY ROOM 2   266763  Francesca
# 1  50646      Pleasant Room along Bukit Timah   227796    Sujatha
# 2  56334                          COZICOMFORT   266763  Francesca
# 3  71609  Ensuite Room (Room 1 & 2) near EXPO   367042    Belinda
# 4  71896      B&B  Room 1 near Airport & EXPO   367042    Belinda
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0        North Region     Woodlands   1.44255  103.79580  Private room     83
# 1      Central Region   Bukit Timah   1.33235  103.78521  Private room     81
# 2        North Region     Woodlands   1.44246  103.79667  Private room     69
# 3         East Region      Tampines   1.34541  103.95712  Private room    206
# 4         East Region      Tampines   1.34567  103.95963  Private room     94
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (7905, 14)

# %%
df['neighbourhood_group'].value_counts()
# Out:
# Central Region       6307
# West Region           540
# East Region           508
# North-East Region     346
# North Region          204
# Name: neighbourhood_group, dtype: int64

# %%
df.head()
# Out:
#       id                                 name  host_id  host_name  \
# 0  49091    COZICOMFORT LONG TERM STAY ROOM 2   266763  Francesca
# 1  50646      Pleasant Room along Bukit Timah   227796    Sujatha
# 2  56334                          COZICOMFORT   266763  Francesca
# 3  71609  Ensuite Room (Room 1 & 2) near EXPO   367042    Belinda
# 4  71896      B&B  Room 1 near Airport & EXPO   367042    Belinda
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0        North Region     Woodlands   1.44255  103.79580  Private room     83
# 1      Central Region   Bukit Timah   1.33235  103.78521  Private room     81
# 2        North Region     Woodlands   1.44246  103.79667  Private room     69
# 3         East Region      Tampines   1.34541  103.95712  Private room    206
# 4         East Region      Tampines   1.34567  103.95963  Private room     94
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
plt.figure(figsize=(15,5))
sns.set_style('darkgrid')
sns.distplot(df['price'])
plt.title('Distplot about room prices')
##It show sthat most of the rooms' prices will be 0-1000
#kde is also present
# Out:
# Text(0.5, 1.0, 'Distplot about room prices')

# %%
df.head()
# Out:
#       id                                 name  host_id  host_name  \
# 0  49091    COZICOMFORT LONG TERM STAY ROOM 2   266763  Francesca
# 1  50646      Pleasant Room along Bukit Timah   227796    Sujatha
# 2  56334                          COZICOMFORT   266763  Francesca
# 3  71609  Ensuite Room (Room 1 & 2) near EXPO   367042    Belinda
# 4  71896      B&B  Room 1 near Airport & EXPO   367042    Belinda
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0        North Region     Woodlands   1.44255  103.79580  Private room     83
# 1      Central Region   Bukit Timah   1.33235  103.78521  Private room     81
# 2        North Region     Woodlands   1.44246  103.79667  Private room     69
# 3         East Region      Tampines   1.34541  103.95712  Private room    206
# 4         East Region      Tampines   1.34567  103.95963  Private room     94
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
plt.figure(figsize=(15,10))
sns.violinplot(data=df,x='room_type',y='price')

# %%
df.head()
# Out:
#       id                                 name  host_id  host_name  \
# 0  49091    COZICOMFORT LONG TERM STAY ROOM 2   266763  Francesca
# 1  50646      Pleasant Room along Bukit Timah   227796    Sujatha
# 2  56334                          COZICOMFORT   266763  Francesca
# 3  71609  Ensuite Room (Room 1 & 2) near EXPO   367042    Belinda
# 4  71896      B&B  Room 1 near Airport & EXPO   367042    Belinda
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0        North Region     Woodlands   1.44255  103.79580  Private room     83
# 1      Central Region   Bukit Timah   1.33235  103.78521  Private room     81
# 2        North Region     Woodlands   1.44246  103.79667  Private room     69
# 3         East Region      Tampines   1.34541  103.95712  Private room    206
# 4         East Region      Tampines   1.34567  103.95963  Private room     94
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(data=df,x='price',y=df['minimum_nights'])
plt.title('Scatterplot')
# Out:
# Text(0.5, 1.0, 'Scatterplot')

# %%
sns.pairplot(data=df)

# %%
df.head()
# Out:
#       id                                 name  host_id  host_name  \
# 0  49091    COZICOMFORT LONG TERM STAY ROOM 2   266763  Francesca
# 1  50646      Pleasant Room along Bukit Timah   227796    Sujatha
# 2  56334                          COZICOMFORT   266763  Francesca
# 3  71609  Ensuite Room (Room 1 & 2) near EXPO   367042    Belinda
# 4  71896      B&B  Room 1 near Airport & EXPO   367042    Belinda
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0        North Region     Woodlands   1.44255  103.79580  Private room     83
# 1      Central Region   Bukit Timah   1.33235  103.78521  Private room     81
# 2        North Region     Woodlands   1.44246  103.79667  Private room     69
# 3         East Region      Tampines   1.34541  103.95712  Private room    206
# 4         East Region      Tampines   1.34567  103.95963  Private room     94
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
sns.countplot(x=df['neighbourhood_group'],color='red')
plt.tight_layout()
plt.title('Countplot for neighbourhood groups')
#Value_Counts()
# Out:
# Text(0.5, 1.0, 'Countplot for neighbourhood groups')

# %%
sns.rugplot(df['price'])

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(df['longitude'],df['latitude'],hue=df['neighbourhood_group'])

# %%
df.head()
# Out:
#       id                                 name  host_id  host_name  \
# 0  49091    COZICOMFORT LONG TERM STAY ROOM 2   266763  Francesca
# 1  50646      Pleasant Room along Bukit Timah   227796    Sujatha
# 2  56334                          COZICOMFORT   266763  Francesca
# 3  71609  Ensuite Room (Room 1 & 2) near EXPO   367042    Belinda
# 4  71896      B&B  Room 1 near Airport & EXPO   367042    Belinda
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0        North Region     Woodlands   1.44255  103.79580  Private room     83
# 1      Central Region   Bukit Timah   1.33235  103.78521  Private room     81
# 2        North Region     Woodlands   1.44246  103.79667  Private room     69
# 3         East Region      Tampines   1.34541  103.95712  Private room    206
# 4         East Region      Tampines   1.34567  103.95963  Private room     94
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
df['price'].head()
#We will lower down the price for boxplot
# Out:
# 0     83
# 1     81
# 2     69
# 3    206
# 4     94
# Name: price, dtype: int64

# %%
df1=df[df['price']<250]

# %%
df1
# Out:
#             id                                               name    host_id  \
# 0        49091                  COZICOMFORT LONG TERM STAY ROOM 2     266763
# 1        50646                    Pleasant Room along Bukit Timah     227796
# 2        56334                                        COZICOMFORT     266763
# 3        71609                Ensuite Room (Room 1 & 2) near EXPO     367042
# 4        71896                    B&B  Room 1 near Airport & EXPO     367042
# 5        71903                         Room 2-near Airport & EXPO     367042
# 6        71907                   3rd level Jumbo room 5 near EXPO     367042
# 7       241503             Long stay at The Breezy East "Leopard"    1017645
# 8       241508            Long stay at The Breezy East "Plumeria"    1017645
# 9       241510            Long stay at The Breezy East "Red Palm"    1017645
# 10      275343  Conveniently located City Room!( (Phone number...    1439258
# ...

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df1,x='neighbourhood_group',y='price')

# %%
df.head()
# Out:
#       id                                 name  host_id  host_name  \
# 0  49091    COZICOMFORT LONG TERM STAY ROOM 2   266763  Francesca
# 1  50646      Pleasant Room along Bukit Timah   227796    Sujatha
# 2  56334                          COZICOMFORT   266763  Francesca
# 3  71609  Ensuite Room (Room 1 & 2) near EXPO   367042    Belinda
# 4  71896      B&B  Room 1 near Airport & EXPO   367042    Belinda
#
#   neighbourhood_group neighbourhood  latitude  longitude     room_type  price  \
# 0        North Region     Woodlands   1.44255  103.79580  Private room     83
# 1      Central Region   Bukit Timah   1.33235  103.78521  Private room     81
# 2        North Region     Woodlands   1.44246  103.79667  Private room     69
# 3         East Region      Tampines   1.34541  103.95712  Private room    206
# 4         East Region      Tampines   1.34567  103.95963  Private room     94
#
#    minimum_nights  number_of_reviews  calculated_host_listings_count  \
# ...

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=df,x='room_type',hue='neighbourhood_group')
plt.title('Countplot for room type categorized by neighbourhood group')
# Out:
# Text(0.5, 1.0, 'Countplot for room type categorized by neighbourhood group')

# %%
plt.figure(figsize=(15,10))
sns.catplot(data=df,x='room_type',y='price')
